# %%
import numpy as np
import pandas as pd
import requests 
from bs4 import BeautifulSoup

# %%
import re

# %%
#Write a function to srap data at one page
def get_page_data(page_number):
    """
    Scrap the content on Goodreads website based on page number
    
    Args:
    page_number(int): the position of the page in the search results, an interger from 1 to 50
    
    Returns: 
    Data Frame with 5 colums: Title, Author, Avg Rating, Total Ratings and Year
    """
    #Specify the params: this will pass page number to the url
    params = {'page':page_number}
    #Specify the url
    url="https://www.goodreads.com/shelf/show/psychology"
    
    
    #Request the content from url and save
    r = requests.get(url, params=params)
    
    #Save the text using Beautiful Soup
    soup = BeautifulSoup(r.text)
    
    #Get titles:
    title = []
    tags_a = soup.find_all('a', class_='leftAlignedImage')
    for i in range(0 , 50):
        title.append(tags_a[i].get('title'))
    
    #Get authors:
    author = []
    tags_span = soup.find_all('span', itemprop='name')
    for j in range(0 , 50):
        author.append(tags_span[j].text)
        
    #Get avg_rating, total_ratings, published_year:
    avg_rating = [] 
    total_ratings = []
    published_year = []
    greytext = soup.find_all(string=re.compile('avg rating'))
    for k in range(0 , 50): 
        avg_rating.append(greytext[k][28:32])
        total_ratings.append(greytext[k][51:58])
        published_year.append(greytext[k][95:100])
        
    df_output = pd.DataFrame(zip(title, author, avg_rating, total_ratings, published_year), columns=['Title','Author', 'Avg Rating', 'Total Ratings', 'Year'])
    return df_output

# %%
df = pd.DataFrame()

# %%
df_output = get_page_data(4)
df_output.head()
# Out:
#                                                Title            Author  \
# 0                            Thinking, Fast and Slow   Daniel Kahneman
# 1                           Man's Search for Meaning  Viktor E. Frankl
# 2  Quiet: The Power of Introverts in a World That...        Susan Cain
# 3      Blink: The Power of Thinking Without Thinking  Malcolm Gladwell
# 4  The Power of Habit: Why We Do What We Do in Li...    Charles Duhigg
#
#   Avg Rating Total Ratings   Year
# 0       4.16       333,012   2011
# 1       4.35       434,272   1946
# 2       4.06       340,576   2012
# 3       3.94       504,406   2005
# 4       4.11       365,421   2012

# %%
#Scrap data from the first 25 page and put into a data frame together
for page_number in [1, 2, 3]:
    df_output = get_page_data(page_number)
    df = pd.concat([df, df_output], axis=0)

# %%
df.describe()
# Out:
#                          Title            Author Avg Rating Total Ratings  \
# count                      150               150        150           150
# unique                      50                40         34            50
# top     Stumbling on Happiness  Malcolm Gladwell       4.06       21,917
# freq                         3                15         12             3
#
#          Year
# count     150
# unique     38
# top      2012
# freq        9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          150 non-null    object
#  1   Author         150 non-null    object
#  2   Avg Rating     150 non-null    object
#  3   Total Ratings  150 non-null    object
#  4   Year           150 non-null    object
# dtypes: object(5)
# memory usage: 7.0+ KB

# %%
df.head(58)
# Out:
#                                                 Title  \
# 0                             Thinking, Fast and Slow
# 1                            Man's Search for Meaning
# 2   Quiet: The Power of Introverts in a World That...
# 3       Blink: The Power of Thinking Without Thinking
# 4   The Power of Habit: Why We Do What We Do in Li...
# 5             Influence: The Psychology of Persuasion
# 6   The Man Who Mistook His Wife for a Hat and Oth...
# 7   Predictably Irrational: The Hidden Forces That...
# 8          Flow: The Psychology of Optimal Experience
# 9                      Outliers: The Story of Success
# 10  The Tipping Point: How Little Things Can Make ...
# 11  The Psychopath Test: A Journey Through the Mad...
# 12  Emotional Intelligence: Why It Can Matter More...
# 13            How to Win Friends and Influence People
# 14             Mindset: The New Psychology of Success
# 15                       The Interpretation of Dreams
# 16  The Body Keeps the Score: Brain, Mind, and Bod...
# 17  The Subtle Art of Not Giving a F*ck: A Counter...
# 18                                Man and His Symbols
# 19            12 Rules for Life: An Antidote to Chaos
# 20  The Righteous Mind: Why Good People Are Divide...
# 21                             Stumbling on Happiness
# 22  The Lucifer Effect: Understanding How Good Peo...
# 23  Drive: The Surprising Truth About What Motivat...
# 24     An Unquiet Mind: A Memoir of Moods and Madness
# 25                                  Games People Play
# 26                                  The Art of Loving
# 27                   Civilization and Its Discontents
# 28                      Memories, Dreams, Reflections
# 29  Talking to Strangers: What We Should Know Abou...
# 30  Daring Greatly: How the Courage to Be Vulnerab...
# 31  The Happiness Hypothesis: Finding Modern Truth...
# 32  Nudge: Improving Decisions About Health, Wealt...
# 33        Grit: The Power of Passion and Perseverance
# 34  The 7 Habits of Highly Effective People: Power...
# 35  The Blank Slate: The Modern Denial of Human Na...
# 36  Maybe You Should Talk to Someone: A Therapist,...
# 37  The Willpower Instinct: How Self-Control Works...
# 38  The Road Less Traveled: A New Psychology of Lo...
# 39                          The Gifts of Imperfection
# 40  Love's Executioner and Other Tales of Psychoth...
# 41  On Becoming a Person: A Therapist's View of Ps...
# 42  David and Goliath: Underdogs, Misfits, and the...
# 43  Atomic Habits: An Easy & Proven Way to Build G...
# 44  You Are Not So Smart: Why You Have Too Many Fr...
# 45                     Modern Man in Search of a Soul
# 46                                 How the Mind Works
# 47            The Paradox of Choice: Why More Is Less
# 48  The Highly Sensitive Person: How to Thrive Whe...
# 49                            The Sociopath Next Door
# 0                             Thinking, Fast and Slow
# 1                            Man's Search for Meaning
# 2   Quiet: The Power of Introverts in a World That...
# 3       Blink: The Power of Thinking Without Thinking
# 4   The Power of Habit: Why We Do What We Do in Li...
# 5             Influence: The Psychology of Persuasion
# 6   The Man Who Mistook His Wife for a Hat and Oth...
# 7   Predictably Irrational: The Hidden Forces That...
#
#                      Author Avg Rating Total Ratings    Year
# 0           Daniel Kahneman       4.16       333,012    2011
# 1          Viktor E. Frankl       4.35       434,272    1946
# 2                Susan Cain       4.06       340,576    2012
# 3          Malcolm Gladwell       3.94       504,406    2005
# 4            Charles Duhigg       4.11       365,421    2012
# 5        Robert B. Cialdini       4.19       108,158    1984
# 6              Oliver Sacks       4.06       172,542    1985
# 7                Dan Ariely       4.12       104,800    2008
# 8   Mihaly Csikszentmihalyi       4.10       58,761   1990\n
# 9          Malcolm Gladwell       4.17       588,313    2008
# 10         Malcolm Gladwell       3.98       709,123    2000
# 11               Jon Ronson       3.94       126,904    2011
# 12           Daniel Goleman       4.02       87,956   1995\n
# 13            Dale Carnegie       4.21       653,599    1936
# 14           Carol S. Dweck       4.06       96,810   2006\n
# 15            Sigmund Freud       3.82       64,377   1899\n
# 16   Bessel A. van der Kolk       4.45       47,075   2014\n
# 17              Mark Manson       3.93       584,225    2016
# 18                C.G. Jung       4.18       21,674   1964\n
# 19       Jordan B. Peterson       3.93       115,789    2018
# 20           Jonathan Haidt       4.20       37,249   2012\n
# 21      Daniel Todd Gilbert       3.82       55,050   2006\n
# 22       Philip G. Zimbardo       3.92       19,319   2007\n
# 23           Daniel H. Pink       3.94       98,358   2009\n
# 24     Kay Redfield Jamison       4.03       65,471   1995\n
# 25               Eric Berne       3.78       28,824   1964\n
# 26              Erich Fromm       4.02       55,928   1956\n
# 27            Sigmund Freud       3.78       33,090   1930\n
# 28                C.G. Jung       4.11       28,600   1961\n
# 29         Malcolm Gladwell       4.03       160,442    2019
# 30              Brené Brown       4.26       141,625    2012
# 31           Jonathan Haidt       4.09       27,823   2006\n
# 32        Richard H. Thaler       3.84       66,019   2008\n
# 33         Angela Duckworth       4.08       76,024   2016\n
# 34         Stephen R. Covey       4.12       551,202    1988
# 35            Steven Pinker       4.07       21,917   2002\n
# 36            Lori Gottlieb       4.37       146,582    2019
# 37          Kelly McGonigal       4.14       27,506   2011\n
# 38            M. Scott Peck       4.06       85,959   1978\n
# 39              Brené Brown       4.20       120,267    2010
# 40           Irvin D. Yalom       4.23       26,030   1989\n
# 41           Carl R. Rogers       4.15       13,878   1961\n
# 42         Malcolm Gladwell       3.95       153,060    2013
# 43              James Clear       4.35       164,768    2018
# 44            David McRaney       3.86       31,899   2011\n
# 45                C.G. Jung       4.19       8,837 r  931\n
# 46            Steven Pinker       3.98       18,583   1997\n
# 47           Barry Schwartz       3.85       29,403   2004\n
# 48           Elaine N. Aron       3.87       33,237   1996\n
# 49             Martha Stout       3.76       32,842   2005\n
# 0           Daniel Kahneman       4.16       333,012    2011
# 1          Viktor E. Frankl       4.35       434,272    1946
# 2                Susan Cain       4.06       340,576    2012
# 3          Malcolm Gladwell       3.94       504,406    2005
# 4            Charles Duhigg       4.11       365,421    2012
# 5        Robert B. Cialdini       4.19       108,158    1984
# 6              Oliver Sacks       4.06       172,542    1985
# 7                Dan Ariely       4.12       104,800    2008

# %%
#Sadly Goodreads seems to block my scraping effort and the page params do not work. You can see that the last 8 records are repetition of the first 8, as instead of scraping page 2, I gave me page 1 again.
